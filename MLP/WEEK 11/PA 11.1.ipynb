# %% [markdown]
# # PA 11.1

# %% [markdown]
# ## (Consider the statement for Q1-Q4)
#
# - Load the iris dataset from sklearn.
# - Remove the rows if it contain NULL values.
# - Train the model Using Kmeans Clustering by setting the parameter as following:
#     - `"init": "random",    "n_init": 50,    "max_iter": 500,    "random_state": 10`

# %%
from sklearn.datasets import load_iris

X,y = load_iris(return_X_y=True , as_frame=True)

# %%
X.isna().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# dtype: int64

# %%
from sklearn.cluster import KMeans

clf = KMeans(init="random" , n_init=50 , max_iter=500 , random_state=10)
clf.fit(X,y)
# Out:
# KMeans(init='random', max_iter=500, n_init=50, random_state=10)

# %% [markdown]
# ### Q1) Which feature pair has the highest correlation cofficient value.
#
# - 'Petal length' and 'Petal Width'
# - 'Petal Width','Sepal Length'
# - 'Petal length' and 'Sepal Length'
# - 'Sepal Width' and 'Sepal Length'

# %%
X.corr()
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.117570           0.871754
# sepal width (cm)           -0.117570          1.000000          -0.428440
# petal length (cm)           0.871754         -0.428440           1.000000
# petal width (cm)            0.817941         -0.366126           0.962865
#
#                    petal width (cm)
# sepal length (cm)          0.817941
# sepal width (cm)          -0.366126
# petal length (cm)          0.962865
# petal width (cm)           1.000000

# %% [markdown]
# ### Q2) Enter the value of the ' inertia_' score Keeping k=5.

# %%
clf = KMeans(n_clusters=5,init="random" , n_init=50 , max_iter=500 , random_state=10)
clf.fit(X,y)
clf.inertia_
# Out:
# 46.44618205128205

# %% [markdown]
# ### Q3) Plot the elbow chart for the given data by taking k=1 to k=12. At which k value elbow is formed?

# %%
inertia_scores = []
for k in range(1 , 12 + 1):
    clf = KMeans(n_clusters=k,init="random" , n_init=50 , max_iter=500 , random_state=10)
    clf.fit(X,y)
    inertia_scores += [clf.inertia_]

# %%
import matplotlib.pyplot as plt 

plt.plot(range(1,12+1) , inertia_scores)

# %% [markdown]
# ### Q4) What is the value of ' inertia_' score at k=3.

# %%
inertia_scores[2]
# Out:
# 78.85144142614601

# %% [markdown]
# ## (Consider the statement for Q5-Q6)
#
# - Load the iris dataset from sklearn.
# - Remove the rows if it contain NULL values.
# - Train the model using Agglomerative Clustering by setting the parameter as following
#     - `n_clusters=3,affinity='euclidean', linkage='ward'`

# %%
from sklearn.datasets import load_iris

X,y = load_iris(return_X_y=True , as_frame=True)

# %%
from sklearn.cluster import AgglomerativeClustering

clf = AgglomerativeClustering(n_clusters=3 , metric='euclidean',linkage='ward')
clf.fit(X,y)
# Out:
# AgglomerativeClustering(n_clusters=3)

# %% [markdown]
# ### Q5) What is the label predicted for last row of samples.

# %%
clf.predict(X.tail(1))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 clf.predict(X.tail(1))
#
# AttributeError: 'AgglomerativeClustering' object has no attribute 'predict'

# %% [markdown]
# ### Q6) Enter the number of leaves in the hierarchical tree.

# %%
clf.n_leaves_
# Out:
# 150
