# %% [markdown]
# # OPPE 2 Mock

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("V1.csv")

# %% [markdown]
# ### Q1) Which dataset are you using for this exam?

# %%
"V1"
# Out:
# 'V1'

# %% [markdown]
# ### Q2) How many total number of rows and columns are there in the dataset?

# %%
df.shape
# Out:
# (20000, 15)

# %% [markdown]
# ### Q3) Is there any Missing values in the given dataset ?

# %%
df.isna().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# IncomeGroup       0
# dtype: int64

# %% [markdown]
# ### Q4) Check all " ?" symbol in the dataset and replace it with "np.nan" value . Which of the columns in the dataset have null values?

# %%
df = df.replace({" ?" : np.nan})

# %%
df.isna().sum()
# Out:
# age                  0
# workclass         1137
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        1140
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     354
# IncomeGroup          0
# dtype: int64

# %% [markdown]
# ### Q5) What fraction of total samples (in percentage) have missing value in occupation column?

# %%
df["occupation"].isna().sum() / df.shape[0]
# Out:
# 0.057

# %% [markdown]
# ### Q6) What fraction of total samples(In percentage) have income <= 50k in the given dataset? (round the value upto 2 decimal places)

# %%
df[df.IncomeGroup == " <=50K"].shape[0]/df.shape[0] * 100
# Out:
# 76.51

# %% [markdown]
# ### Q7) What is the mean age of the samples given in the dataset(mark the closest integer from the given options)?

# %%
df.age.mean()
# Out:
# 38.553

# %% [markdown]
# ### Q8) How many people have completed their education upto "Preschool" only ?

# %%
df[df.education == " Preschool"].shape[0]
# Out:
# 32

# %% [markdown]
# ### Q9) What is the correlation cofficient between column "education-num" and column "capital-gain" ?

# %%
df[["education-num" , "capital-gain"]].corr()
# Out:
#                education-num  capital-gain
# education-num       1.000000      0.124567
# capital-gain        0.124567      1.000000

# %% [markdown]
# ### Q10) Apply SimpleImputer with strategy = 'most_frequent' to replace all NaN value by mode of respective column in the original dataset.(Use this updated dataset only for all further questions)
#
# What is the mode of 'occupation' column of updated datset?

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy="most_frequent")
new_df = pd.DataFrame(imputer.fit_transform(df) , columns=imputer.get_feature_names_out())

# %%
new_df["occupation"].mode()
# Out:
# 0     Prof-specialty
# Name: occupation, dtype: object

# %% [markdown]
# ### Q11) Split the dataset into X1, X2 and y, where X1 contains all Numerical features, X2 contains all categorical features(except "IncomeGroup") and save 'IncomeGroup' column in y variable. Then apply OneHotEncoder on the categorical features(X2) with option (sparse = False) and StandardScaler on the numerical features (X2).
#
# What is the total number of columns in X1 and X2 variables respectively?

# %%
X1 = new_df.select_dtypes("int64")

# %%
X1 = new_df.apply(pd.to_numeric , errors='ignore').select_dtypes('int64')
X2 = new_df.apply(pd.to_numeric , errors='ignore').select_dtypes('object').drop(columns=["IncomeGroup"])
y = new_df.IncomeGroup
# Out:
# /tmp/ipykernel_258968/1504571791.py:1: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   X1 = new_df.apply(pd.to_numeric , errors='ignore').select_dtypes('int64')
# /tmp/ipykernel_258968/1504571791.py:2: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   X2 = new_df.apply(pd.to_numeric , errors='ignore').select_dtypes('object').drop(columns=["IncomeGroup"])

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler

scaler = StandardScaler()
X1_new = scaler.fit_transform(X1)
X1_new.shape[1]
# Out:
# 6

# %%
ohe = OneHotEncoder(sparse_output=False)
X2_new = ohe.fit_transform(X2)
X2_new.shape[1]
# Out:
# 99

# %% [markdown]
# ### Q12) Apply StandardScaler on the X1 data and OneHotEncoder on X2 data with option (sparse = False).
#
# What are the data types of X1 and X2?

# %%
type(X1_new) , type(X2_new)
# Out:
# (numpy.ndarray, numpy.ndarray)

# %% [markdown]
# ### Q13) Concatenate X1 and X2 and call it X( Keep axis = 1) and then Convert X to a dataframe.
# What is the new shape of resultant X?

# %%
X = pd.concat([
    pd.DataFrame(X1_new , columns=scaler.get_feature_names_out()),
    pd.DataFrame(X2_new , columns=ohe.get_feature_names_out())
] , axis=1)

# %%
X.shape
# Out:
# (20000, 105)

# %% [markdown]
# ### Q14) Split the dataset into training and validation dataset into 80:20 ratio while keeping random_state =64. what is the shape of the y_train dataset?

# %%
from sklearn.model_selection import train_test_split

X_train , X_test , y_train , y_test = train_test_split(X,y , test_size=0.2 , random_state=64)

# %%
y_train.shape
# Out:
# (16000,)

# %% [markdown]
# ### Q15) Instantiate a perceptron classifier that with following parameters:-
#
# - Fit the intercept
# - Put warm start to be False
#
# Fit this perceptron model with the training dataset and calculate the accuracy score for training data. Which of the following option matches with the score?

# %%
from sklearn.linear_model import Perceptron

clf = Perceptron(fit_intercept=True , warm_start=False)
clf.fit(X_train , y_train)
clf.score(X_train , y_train)
# Out:
# 0.813

# %% [markdown]
# ### Q16) Create a new Perceptron object with given settings in the instrunctions and train it on training set . What is the value of bias (intercept) (upto 1 decimal point) ?
#
# - Set early stopping and fit interceptto be True
#  - Put warm start to be False

# %%
from sklearn.linear_model import Perceptron

clf = Perceptron(fit_intercept=True , warm_start=False , early_stopping=True)
clf.fit(X_train , y_train)
clf.intercept_
# Out:
# array([-6.])

# %% [markdown]
# ### Q17) Use SGDClassifier on the training dataset (X_train and y_train) to train the model. Use the following parameters:
#
# - log is the loss function to be used
# - apply ridge regularization,
# - maximum number of passes over the training data is 10
# - initial learning rate is 0.01,
# - regularization rate value is 0.001,
# - learning rate should not change during training.
# - Take random_state=64.
# - Set warm_state as False
#
# Note : Please ignore the convergence warning.
#
# Based on this operation, calculate and enter the correct value of accuracy (Upto 4 decimal points).

# %%
from sklearn.linear_model import SGDClassifier

clf = SGDClassifier(loss='log_loss' , penalty='l2' , max_iter=10 , alpha=0.001 , eta0=0.01 , learning_rate='constant'
                   , random_state=64 , warm_start=False)

clf.fit(X_train , y_train)
clf.score(X_test ,y_test)
# Out:
# 0.84825

# %% [markdown]
# ### Q18) Take LogisticRegression estimator with following parameters for fitting on the training dataset:
#
# - Use sag as solver
# - Set random state to be equal to 64
# - Tolerance for stopping criteria to be 1e-3
# - Maximum number of iterations taken for the solvers to converge to be 100
#
# Enter the recall score you got for the given model (Take average as macro).

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression(solver='sag' , random_state=64 , tol=1e-3 , max_iter=100)
clf.fit(X_train , y_train)
# Out:
# /home/tejasvmaheshwari/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# LogisticRegression(random_state=64, solver='sag', tol=0.001)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test , clf.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#        <=50K       0.88      0.93      0.90      3074
#         >50K       0.70      0.58      0.64       926
#
#     accuracy                           0.85      4000
#    macro avg       0.79      0.75      0.77      4000
# weighted avg       0.84      0.85      0.84      4000

# %% [markdown]
# ### Q19) Use Gridsearchcv with KNeighborsClassifier() being the estimator, accuracy as scoring parameter, cv value as 4 and consider [1,3,5,7] as "number of neighbors" to be examined.
#
# Consider following parameters for KNeighborsClassifier():
#
# - Take metric as 'minkowski',
# - Set P value as 2
# - Keep other parameter values as default value.
#
# What is the best value of K you obtained using above instruction?

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier

params = {
    "n_neighbors" : [1,3,5,7]
}

grid = GridSearchCV(KNeighborsClassifier(metric='minkowski') , params , cv=4)
grid.fit(X_train , y_train)
# Out:
# GridSearchCV(cv=4, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': [1, 3, 5, 7]})

# %%
grid.best_params_
# Out:
# {'n_neighbors': 7}

# %% [markdown]
# ## (Common Instruction for Q20 to Q23)
#
# Take DecisionTreeClassifier(random_state = 64) with GridSearchCV to train the model.Hyperparameter tuning to be done over the following parameters:
#
# - Use criterion as 'entropy' or 'gini'
# - Use splitter as 'random' or 'best'
# - Use minimum number of samples per leaf as [2,4,6,8,10]
# - Use maximum depth as [3,4,5,6]
# - Use cross validation = 4

# %% [markdown]
# ### Q20) Enter the value (up to 2 decimal points) of the 'score' on testing set using best model.

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

params = {
    'criterion' : ["entropy" , "gini"],
    "splitter" : ["random" , "best"],
    "min_samples_leaf" : [2,4,6,8,10],
    "max_depth" : [3,4,5,6]
}

grid = GridSearchCV(DecisionTreeClassifier(random_state=64) , params , cv=4)
grid.fit(X_train , y_train)
# Out:
# GridSearchCV(cv=4, estimator=DecisionTreeClassifier(random_state=64),
#              param_grid={'criterion': ['entropy', 'gini'],
#                          'max_depth': [3, 4, 5, 6],
#                          'min_samples_leaf': [2, 4, 6, 8, 10],
#                          'splitter': ['random', 'best']})

# %%
grid.score(X_test , y_test)
# Out:
# 0.84975

# %% [markdown]
# ### Q21) Enter the value of best max_depth of the model after training with GridSearchCV.

# %%
grid.best_estimator_.max_depth
# Out:
# 6

# %% [markdown]
# ### Q22) Enter the value of best min_samples_leaf of the model after training with GridSearchCV.

# %%
grid.best_estimator_.min_samples_leaf
# Out:
# 10

# %% [markdown]
# ### Q23) What are the number of nodes in the optimal tree?

# %%
grid.best_estimator_.tree_.node_count
# Out:
# 75

# %% [markdown]
# ### Q24) Take RandomForestClassifier (random state to be 64) with GridSearchCV to tune the number of decision trees with training set. The number of trees in forest can range from 5 to 10 (both inclusive). Mark the number of decision trees that will produce the best score on the training data.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

params = {
    "n_estimators" : range(5,11)
}

grid = GridSearchCV(RandomForestClassifier(random_state=64) , params)
grid.fit(X_train , y_train)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(random_state=64),
#              param_grid={'n_estimators': range(5, 11)})

# %%
grid.best_params_
# Out:
# {'n_estimators': 10}

# %% [markdown]
# ## (Common Instructions for Q25,Q26)
# - Take an adaboost model with following hyperparameter values and tune it using GridsearchCV.
# - Use n_estimators as [10,20,30]
# - random_state = 64
# - Use learning_rate as [0.5,1,2]
# - Take cv value= 4

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import GridSearchCV

params = {
    "n_estimators" : [10,20,30],
    "learning_rate" : [0.5,1,2],
}

grid = GridSearchCV(AdaBoostClassifier(random_state=64) , params , cv=4)
grid.fit(X_train , y_train)
# Out:
# /home/tejasvmaheshwari/.local/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /home/tejasvmaheshwari/.local/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /home/tejasvmaheshwari/.local/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /home/tejasvmaheshwari/.local/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /home/tejasvmaheshwari/.local/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /home/tejasvmaheshwari/.local/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /home/tejasvmaheshwari/.local/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /home/tejasvmaheshwari/.local/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /home/tejasvmaheshwari/.local/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /home/tejasvmaheshwari/.local/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /home/tejasvmaheshwari/.local/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /home/tejasvmaheshwari/.local/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /home/tejasvmaheshwari/.local/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /home/tejasvmaheshwari/.local/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /home/tejasvmaheshwari/.local/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /home/tejasvmaheshwari/.local/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /home/tejasvmaheshwari/.local/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /home/tejasvmaheshwari/.local/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /home/tejasvmaheshwari/.local/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /home/tejasvmaheshwari/.local/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /home/tejasvmaheshwari/.local/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /home/tejasvmaheshwari/.local/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /home/tejasvmaheshwari/.local/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /home/tejasvmaheshwari/.local/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /home/tejasvmaheshwari/.local/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /home/tejasvmaheshwari/.local/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /home/tejasvmaheshwari/.local/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /home/tejasvmaheshwari/.local/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /home/tejasvmaheshwari/.local/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /home/tejasvmaheshwari/.local/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /home/tejasvmaheshwari/.local/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /home/tejasvmaheshwari/.local/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /home/tejasvmaheshwari/.local/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /home/tejasvmaheshwari/.local/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /home/tejasvmaheshwari/.local/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /home/tejasvmaheshwari/.local/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /home/tejasvmaheshwari/.local/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# GridSearchCV(cv=4, estimator=AdaBoostClassifier(random_state=64),
#              param_grid={'learning_rate': [0.5, 1, 2],
#                          'n_estimators': [10, 20, 30]})

# %% [markdown]
# ### Q25) Train the 'model' using above instructions and enter the 'accuracy score' (up to 3 decimal points) on the test data.

# %%
grid.score(X_test , y_test)
# Out:
# 0.853

# %% [markdown]
# ### Q26) Enter the value of best n_estimators of the model after training with GridSearchCV.

# %%
grid.best_estimator_.n_estimators
# Out:
# 30

# %% [markdown]
# ### Q27) Apply GridsearchCV and support vector machine (SVM)(kernel':('linear', 'rbf'), 'C':[1, 10]) on the training dataset X_train, y_train and calculate the best value of C and kernel. Which of the following options represent the best parameters. (Keep patience: It is common if it takes arround 5 min to complete the run.)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

params = {
    "kernel" : ["linear" , "rbf"],
    "C" : [1,10]
}

grid = GridSearchCV(SVC(), params)
grid.fit(X_train , y_train)
# Out:
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [1, 10], 'kernel': ['linear', 'rbf']})

# %%
grid.best_params_
# Out:
# {'C': 1, 'kernel': 'rbf'}
