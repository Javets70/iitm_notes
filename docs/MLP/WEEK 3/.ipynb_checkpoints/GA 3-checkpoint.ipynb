# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("DataPreprocessingGraded_dataset.csv")
df.head()
# Out:
#     V1    V2       V3    V4        V5 Target
# 0  2.0  50.0  12500.0  98.0  NEGATIVE    YES
# 1  0.0  13.0   3250.0  28.0  NEGATIVE    YES
# 2    ?     ?   4000.0  35.0  NEGATIVE    YES
# 3    ?  20.0   5000.0  45.0  NEGATIVE    YES
# 4  1.0  24.0   6000.0  77.0  NEGATIVE     NO

# %%
df.replace("?" , np.nan , inplace=True)
X,y = df.drop(columns='Target') , df.Target
X,y
# Out:
# (       V1    V2       V3    V4        V5
#  0     2.0  50.0  12500.0  98.0  NEGATIVE
#  1     0.0  13.0   3250.0  28.0  NEGATIVE
#  2     NaN   NaN   4000.0  35.0  NEGATIVE
#  3     NaN  20.0   5000.0  45.0  NEGATIVE
#  4     1.0  24.0   6000.0  77.0  NEGATIVE
#  ..    ...   ...      ...   ...       ...
#  743  23.0   2.0    500.0  38.0  NEGATIVE
#  744  21.0   2.0    500.0  52.0  NEGATIVE
#  745  23.0   3.0    750.0  62.0  NEGATIVE
#  746  39.0   1.0    250.0  39.0  NEGATIVE
#  747  72.0   1.0    250.0  72.0  NEGATIVE
#
#  [748 rows x 5 columns],
#  0      YES
#  1      YES
#  2      YES
#  3      YES
#  4       NO
#        ...
#  743     NO
#  744     NO
#  745     NO
#  746     NO
#  747     NO
#  Name: Target, Length: 748, dtype: object)

# %% [markdown]
# #### Q1) How many features remain after applying following pipeline to the feature matrix?
# ![image.png](attachment:ce4bf4ba-1802-4d11-ab57-120cc02ce0d3.png)

# %%
from sklearn.pipeline import Pipeline,FeatureUnion
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler,OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.feature_selection import VarianceThreshold



num_transformer1 = ColumnTransformer(transformers=[
    ("simple_imputer" , SimpleImputer(missing_values=np.nan,strategy="mean") , [0,1]),
] , remainder="passthrough" , verbose_feature_names_out=False).set_output(transform="pandas")

num_transformer2 = ColumnTransformer(transformers=[
    ("standard_scaler" , StandardScaler() , [0,1,2,3]),
],remainder="passthrough" , verbose_feature_names_out=False).set_output(transform="pandas")

cat_transformer = ColumnTransformer(transformers=[
    ("pass" , "passthrough" , [0,1,2,3]),
    ("ordinal_encoder" , OrdinalEncoder() , [4])
],remainder="passthrough" , verbose_feature_names_out=False).set_output(transform="pandas")


full_pipeline = Pipeline(steps=[
    ("impute" , num_transformer1),
    ("scale" , num_transformer2),
    ("encode" , cat_transformer),
])

full_pipeline.fit_transform(X)
# Out:
#            x0        x1        x2        x3   x4
# 0   -0.938169  7.709867  7.623346  2.615633  0.0
# 1   -1.186278  1.304549  1.282738 -0.257881  0.0
# 2         0.0      -0.0  1.796842  0.029471  0.0
# 3         0.0  2.516366  2.482313  0.439973  0.0
# 4   -1.062223  3.208833  3.167784  1.753579  0.0
# ..        ...       ...       ...       ...  ...
# 743  1.666966 -0.599734 -0.602307  0.152621  0.0
# 744  1.418858 -0.599734 -0.602307  0.727324  0.0
# 745  1.666966 -0.426617  -0.43094  1.137826  0.0
# 746  3.651831 -0.772851 -0.773675  0.193671  0.0
# 747  7.745616 -0.772851 -0.773675  1.548328  0.0
#
# [748 rows x 5 columns]

# %%
from sklearn import set_config
set_config(display="diagram")

full_pipeline
# Out:
# Pipeline(steps=[('impute',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('simple_imputer',
#                                                   SimpleImputer(), [0, 1])])),
#                 ('scale',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('standard_scaler',
#                                                   StandardScaler(),
#                                                   [0, 1, 2, 3])])),
#                 ('encode',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('pass', 'passthrough',
#                                                   [0, 1, 2, 3]),
#                                                  ('ordinal_encoder',
#                                                   OrdinalEncoder(), [4])]))])

# %%
X
# Out:
#        V1    V2       V3    V4        V5
# 0     2.0  50.0  12500.0  98.0  NEGATIVE
# 1     0.0  13.0   3250.0  28.0  NEGATIVE
# 2     NaN   NaN   4000.0  35.0  NEGATIVE
# 3     NaN  20.0   5000.0  45.0  NEGATIVE
# 4     1.0  24.0   6000.0  77.0  NEGATIVE
# ..    ...   ...      ...   ...       ...
# 743  23.0   2.0    500.0  38.0  NEGATIVE
# 744  21.0   2.0    500.0  52.0  NEGATIVE
# 745  23.0   3.0    750.0  62.0  NEGATIVE
# 746  39.0   1.0    250.0  39.0  NEGATIVE
# 747  72.0   1.0    250.0  72.0  NEGATIVE
#
# [748 rows x 5 columns]

# %%
full_pipeline.fit(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 full_pipeline.fit(X)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/pipeline.py:1589, in FeatureUnion.fit(self, X, y, **fit_params)
#    1570 """Fit all transformers using X.
#    1571
#    1572 Parameters
#    (...)
#    1586     FeatureUnion class instance.
#    1587 """
#    1588 _raise_for_unsupported_routing(self, "fit", **fit_params)
# -> 1589 transformers = self._parallel_func(X, y, fit_params, _fit_one)
#    1590 if not transformers:
#    1591     # All transformers are None
#    1592     return self
#
# File ~/.local/lib/python3.10/site-packages/sklearn/pipeline.py:1642, in FeatureUnion._parallel_func(self, X, y, fit_params, func)
#    1638 transformers = list(self._iter())
#    1640 params = Bunch(fit=fit_params, fit_transform=fit_params)
# -> 1642 return Parallel(n_jobs=self.n_jobs)(
#    1643     delayed(func)(
#    1644         transformer,
#    1645         X,
#    1646         y,
#    1647         weight,
#    1648         message_clsname="FeatureUnion",
#    1649         message=self._log_message(name, idx, len(transformers)),
#    1650         params=params,
#    1651     )
#    1652     for idx, (name, transformer, weight) in enumerate(transformers, 1)
#    1653 )
#
# File ~/.local/lib/python3.10/site-packages/sklearn/utils/parallel.py:67, in Parallel.__call__(self, iterable)
#      62 config = get_config()
#      63 iterable_with_config = (
#      64     (_with_config(delayed_func, config), args, kwargs)
#      65     for delayed_func, args, kwargs in iterable
#      66 )
# ---> 67 return super().__call__(iterable_with_config)
#
# File ~/.local/lib/python3.10/site-packages/joblib/parallel.py:1863, in Parallel.__call__(self, iterable)
#    1861     output = self._get_sequential_output(iterable)
#    1862     next(output)
# -> 1863     return output if self.return_generator else list(output)
#    1865 # Let's create an ID that uniquely identifies the current call. If the
#    1866 # call is interrupted early and that the same instance is immediately
#    1867 # re-used, this id will be used to prevent workers that were
#    1868 # concurrently finalizing a task from the previous call to run the
#    1869 # callback.
#    1870 with self._lock:
#
# File ~/.local/lib/python3.10/site-packages/joblib/parallel.py:1792, in Parallel._get_sequential_output(self, iterable)
#    1790 self.n_dispatched_batches += 1
#    1791 self.n_dispatched_tasks += 1
# -> 1792 res = func(*args, **kwargs)
#    1793 self.n_completed_tasks += 1
#    1794 self.print_progress()
#
# File ~/.local/lib/python3.10/site-packages/sklearn/utils/parallel.py:129, in _FuncWrapper.__call__(self, *args, **kwargs)
#     127     config = {}
#     128 with config_context(**config):
# --> 129     return self.function(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/pipeline.py:1319, in _fit_one(transformer, X, y, weight, message_clsname, message, params)
#    1315 """
#    1316 Fits ``transformer`` to ``X`` and ``y``.
#    1317 """
#    1318 with _print_elapsed_time(message_clsname, message):
# -> 1319     return transformer.fit(X, y, **params["fit"])
#
# File ~/.local/lib/python3.10/site-packages/sklearn/base.py:1351, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1344     estimator._validate_params()
#    1346 with config_context(
#    1347     skip_parameter_validation=(
#    1348         prefer_skip_nested_validation or global_skip_validation
#    1349     )
#    1350 ):
# -> 1351     return fit_method(estimator, *args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/pipeline.py:470, in Pipeline.fit(self, X, y, **params)
#     423 @_fit_context(
#     424     # estimators in Pipeline.steps are not validated yet
#     425     prefer_skip_nested_validation=False
#     426 )
#     427 def fit(self, X, y=None, **params):
#     428     """Fit the model.
#     429
#     430     Fit all the transformers one after the other and sequentially transform the
#    (...)
#     468         Pipeline with fitted steps.
#     469     """
# --> 470     routed_params = self._check_method_params(method="fit", props=params)
#     471     Xt = self._fit(X, y, routed_params)
#     472     with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#
# File ~/.local/lib/python3.10/site-packages/sklearn/pipeline.py:360, in Pipeline._check_method_params(self, method, props, **kwargs)
#     357     return routed_params
#     358 else:
#     359     fit_params_steps = Bunch(
# --> 360         **{
#     361             name: Bunch(**{method: {} for method in METHODS})
#     362             for name, step in self.steps
#     363             if step is not None
#     364         }
#     365     )
#     366     for pname, pval in props.items():
#     367         if "__" not in pname:
#
# File ~/.local/lib/python3.10/site-packages/sklearn/pipeline.py:362, in <dictcomp>(.0)
#     357     return routed_params
#     358 else:
#     359     fit_params_steps = Bunch(
#     360         **{
#     361             name: Bunch(**{method: {} for method in METHODS})
# --> 362             for name, step in self.steps
#     363             if step is not None
#     364         }
#     365     )
#     366     for pname, pval in props.items():
#     367         if "__" not in pname:
#
# ValueError: too many values to unpack (expected 2)
